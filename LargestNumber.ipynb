# %%
print("====== LIST ======")
list=[1,2,3,4,2,7,3]
num=list[0]
for i in range (len(list)):
    if list[i] > num:
        num = list[i]
print("Largest Number: ",num)
print("====== ==== ======")
# Out:
# ====== LIST ======
# Largest Number:  7
# ====== ==== ======
