# %%
print("===== AERA OF CIRCLE =======")
radius=float(input("Enter radius of the circle: "))
PI=3.142
# Out:
# ===== AERA OF CIRCLE =======
# Enter radius of the circle:  4

# %%
Area=PI*radius*radius

# %%
print("Area of Circle is: ",Area)
# Out:
# Area of Circle is:  50.272
