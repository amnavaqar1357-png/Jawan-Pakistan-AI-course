# %%
x=input("Enter First Name: ")
y=input("Enter Last Name: ")
# Out:
# Enter First Name:  Amna
# Enter Last Name:  Vaqar

# %%
name=[x,y]
name.reverse()

# %%
print(name[0],name[1])
# Out:
# Vaqar Amna
