# %%
print("======= List ========")
Number=[1,2,2,4,5,5,7]
print(Number)
print("Size of List: ",len(Number))
print("=====================")
# Out:
# ======= List ========
# [1, 2, 2, 4, 5, 5, 7]
# Size of List:  7
# ...
