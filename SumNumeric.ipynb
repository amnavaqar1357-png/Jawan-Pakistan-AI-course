# %%
print("======== LIST ========")
list=["Cat",1,4,"Bird"]
sum=0
for i in range(len(list)):
    if isinstance(list[i], int):
        sum += list[i]
print("Sum= ",sum)
print("======= ======= =======")
# Out:
# ======== LIST ========
# Sum=  5
# ======= ======= =======
